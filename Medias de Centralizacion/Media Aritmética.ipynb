# %%
import pandas as pd
import os
import numpy as np

# %%
mainpath = "/Users/Cruz/Documents/Inteligencia"
filename = "lfc_manager.txt"
fullpath = os.path.join(mainpath,filename)

# %%
data = pd.read_csv(fullpath)

# %%
data
# Out:
#                  Name       Nationality        From          To    P    W  \
# 0       McKenna, John           Ireland  1892-02-15  1896-08-16  127   77
# 1         Watson, Tom           England  1896-08-17  1915-05-06  742  329
# 2   Patterson, George           England  1915-06-01  1919-12-14   18    7
# 3     Ashworth, David           England  1919-12-18  1923-02-12  139   70
# 4       McQueen, Matt          Scotland  1923-02-13  1928-02-15  229   93
# 5   Patterson, George           England  1928-03-07  1936-08-06  366  137
# 6         Kay, George           England  1936-08-06  1951-03-22  357  142
# 7          Welsh, Don           England  1951-03-23  1956-05-04  232   81
# 8        Taylor, Phil           England  1956-05-05  1959-11-17  150   76
# 9       Shankly, Bill          Scotland  1959-12-01  1974-07-12  783  407
# 10       Paisley, Bob           England  1974-08-26  1983-07-01  535  308
# 11         Fagan, Joe           England  1983-07-02  1985-05-29  131   71
# ...

# %%
#Media

# %%
data["win_perc"].mean()
# Out:
# 47.995

# %%
#Moda

# %%
data["win_perc"].mode()
# Out:
# 0     34.91
# 1     37.43
# 2     38.89
# 3     39.78
# 4     40.00
# 5     40.61
# 6     41.94
# 7     42.04
# 8     44.34
# 9     47.30
# 10    50.00
# 11    50.36
# 12    50.67
# 13    51.77
# 14    51.98
# 15    52.12
# 16    53.01
# 17    54.20
# 18    55.43
# 19    57.57
# 20    60.63
# 21    60.91
# dtype: float64

# %%
#Mediana

# %%
data["win_perc"].median()
# Out:
# 50.18

# %%
#percentiles

# %%
a = data["win_perc"]

# %%
np.percentile(a,50)
# Out:
# 50.18
